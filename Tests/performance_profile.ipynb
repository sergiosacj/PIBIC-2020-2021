# %%
using BenchmarkProfiles, Plots
AF = [
[ 26     14];
[ 32     19];
[ 8      3 ];
[ 16     84];
[ 22     5 ];
[ 144    8 ];
[ 52     17];
[ 4      2 ];
[ 998    23];
[ 0      3 ];
[ 38     8 ];
[ 60     28];
[ 12     13];
[ 42     25];
[ 0      1 ];
[ 0      5 ];
[ 14     45];
[ 42     17];
]

AF = convert(Array{Float64}, AF)
performance_profile(PlotsBackend(), AF, ["ARp", "Ipopt"], title="AF")
# Out:
# ┌ Warning: some measures are zero; shifting all by one
# └ @ BenchmarkProfiles /home/sergiosacj/.julia/packages/BenchmarkProfiles/06x4X/src/performance_profiles.jl:14
