# %%
using BenchmarkProfiles, Plots
AF = [                                                                       
[2     2];                                                                         
[8     3];                                                                         
[22    8];                                                                         
[17    19];                                                                        
[18    12];                                                                        
[14    14];                                                                        
[21    5];                                                                         
[90    8];                                                                         
[11    8];                                                                         
[11    17];                                                                        
[14    54];                                                                        
[8     13];                                                                        
[11    50];                                                                        
[25    25];                                                                        
[11    10];                                                                        
[15    23];                                                                        
[34    47];                                                                        
[24    37];                                                                        
[11    24];                                                                        
[10    24];                                                                        
[13    10];                                                                        
[21    17];                                                                        
[20    45];                                                                        
[6     13];                                                                        
[47    28];                                                                        
[49    17];                                                                        
[38    84];
]

AF = convert(Array{Float64}, AF)
performance_profile(PlotsBackend(), AF, ["ARp", "Ipopt"], title="AF")

# %%
using BenchmarkProfiles, Plots
AF = [                                                                       
[2     2];                                                                         
[22    8];                                                                         
[17    19];                                                                        
[14    14];                                                                        
[90    8];
[25    25];
[13    10];                                                                        
[21    17];                                                                        
[20    45];                                                                        
[6     13];                                                                        
[47    28];                                                                        
[49    17];                                                                        
[38    84];
]

AF = convert(Array{Float64}, AF)
performance_profile(PlotsBackend(), AF, ["ARp", "Ipopt"], title="AF")
